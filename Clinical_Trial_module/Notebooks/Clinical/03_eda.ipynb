# %%
import pandas as pd

df = pd.read_csv("../../data/clinical_processed/cleaned_data.csv")

print(df.head())
print(df.describe())
print(df['target'].value_counts())
# Out:
#   study_status  phases  enrollment      study_type funder_type  start_date  \
# 0   TERMINATED  PHASE2        10.0  INTERVENTIONAL       OTHER  2020-10-23
# 1    COMPLETED  PHASE2        60.0  INTERVENTIONAL       OTHER  2018-12-05
# 2    COMPLETED  PHASE2      1808.0  INTERVENTIONAL    INDUSTRY  2020-06-15
# 3    COMPLETED  PHASE1        16.0  INTERVENTIONAL    INDUSTRY  2018-06-25
# 4    COMPLETED  PHASE2        18.0  INTERVENTIONAL    INDUSTRY  2021-03-09
#
#   completion_date  target  duration_months
# 0      2023-12-31       0        38.800000
# 1      2024-02-28       1        63.700000
# 2      2022-02-18       1        20.433333
# 3      2018-09-06       1         2.433333
# 4      2024-07-15       1        40.800000
#          enrollment        target  duration_months
# count  9.593200e+04  95932.000000     95932.000000
# mean   3.380053e+02      0.512446        36.617857
# std    1.195715e+04      0.499848        33.891649
# ...
