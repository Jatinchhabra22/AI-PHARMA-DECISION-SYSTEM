# %% [markdown]
# """
# # Clinical Trial Success Prediction
#
# ## Objective
# Predict whether a clinical trial will succeed (Completed) or fail.
#
# ## Approach
# Use structured features like:
# - Phase
# - Enrollment
# - Duration
# - Study Type
# - Funder Type
#
# ## Output
# Probability of success
# """
